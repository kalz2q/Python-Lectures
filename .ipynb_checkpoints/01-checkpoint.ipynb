# %% [markdown]
# All the IPython Notebooks in this lecture series are available at https://github.com/rajathkumarmp/Python-Lectures

# %% [markdown]
# # The Zen Of Python

# %%
# import this
# うざい

# %%
# import that

# %% [markdown]
# # Variables 変数

# %% [markdown]
# A name that is used to denote something or a value is called a variable. In python, variables can be declared and values can be assigned to it as follows,

# %%
x = 2
y = 5
xy = 'Hey'

# %%
print (x+y, xy)
# Out:
# 7 Hey

# %% [markdown]
# Multiple variables can be assigned with the same value.

# %%
x = y = 1 # 一度に代入できるのはよくないと思います

# %%
print (x,y)
# Out:
# 1 1

# %% [markdown]
# # Operators 演算子

# %% [markdown]
# ## Arithmetic Operators

# %% [markdown]
# | Symbol | Task Performed |
# |----|---|
# | +  | Addition |
# | -  | Subtraction |
# | /  | division |
# | %  | mod |
# | *  | multiplication |
# | //  | floor division |
# | **  | to the power of |

# %%
# 加算+ 減算- 割り算/ 余り% 掛け算* 整数割り算// 乗算**

# %%
1+2
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
1*2
# Out:
# 2

# %%
1/2 # 0.5であって0ではないのはpython3からかな
# Out:
# 0.5

# %%
1/2.0
# Out:
# 0.5

# %%
-15 // 2 # -8であって-7ではない。floor divisionである
# Out:
# -8

# %%
-14.2 // 2 # -8であって-7ではない。四捨五入ではない。floor divisionである
# Out:
# -8.0

# %%
15%10
# Out:
# 5

# %%
2.8//2.0
# Out:
# 1.0

# %% [markdown]
# ### 質問 有理数計算はできますか。1/2 + 1/3 => 5/6みたいの

# %%
import fractions
fractions.Fraction(1, 2) + fractions.Fraction(1,3)
# Out:
# Fraction(5, 6)

# %% [markdown]
# ## Relational Operators 関係演算子

# %% [markdown]
# | Symbol | Task Performed |
# |----|---|
# | == | True, if it is equal |
# | !=  | True, if not equal to |
# | < | less than |
# | > | greater than |
# | <=  | less than or equal to |
# | >=  | greater than or equal to |

# %%
# 等号

# %%
z = 1

# %%
z == 1
# Out:
# True

# %%
z > 1
# Out:
# False

# %% [markdown]
# ## ビット演算子 Bitwise Operators

# %% [markdown]
# | Symbol | Task Performed |
# |----|---|
# | &  | Logical And |
# | l  | Logical OR |
# | ^  | XOR |
# | ~  | Negate |
# | >>  | Right shift |
# | <<  | Left shift |

# %%
a = 2 #10
b = 3 #11

# %%
print a & b
print bin(a&b)
# Out:
# 2
# 0b10

# %%
5 >> 1
# Out:
# 2

# %% [markdown]
# 0000 0101 -> 5
#
# Shifting the digits by 1 to the right and zero padding
#
# 0000 0010 -> 2

# %%
5 << 1
# Out:
# 10

# %% [markdown]
# 0000 0101 -> 5
#
# Shifting the digits by 1 to the left and zero padding
#
# 0000 1010 -> 10

# %% [markdown]
# # ビルトイン関数 Built-in Functions

# %% [markdown]
# Python comes loaded with pre-built functions

# %% [markdown]
# ## 数値変換 Conversion from one system to another
# 数値ベース変換, 基数変換,n進法変換

# %% [markdown]
# Conversion from hexadecimal to decimal is done by adding prefix **0x** to the hexadecimal value or vice versa by using built in **hex( )**, Octal to decimal by adding prefix **0** to the octal value or vice versa by using built in function **oct( )**.

# %% [markdown]
# 数字の頭に`0x`をつければ16進法の数字。16進法にする関数は`hex()`。
#
# 8進法は数字の頭に`0`をつけるだけ。8進法にする関数は`oct()`。

# %%
hex(170)
# Out:
# '0xaa'

# %%
0xAA
# Out:
# 170

# %%
oct(8)
# Out:
# '010'

# %%
010
# Out:
# 8

# %% [markdown]
# **int( )** accepts two values when used for conversion, one is the value in a different number system and the other is its base. Note that input number in the different number system should be of string type.

# %% [markdown]
# `int( )`関数は引数を2つ取り1つ目は文字列で表された数字で2つめはそのベースとなる基数です。
#
# ということは不要か。
#
# だって `int('010',8)`ってただ0o10と書いてもおなじではないか。

# %%
print (int('010',8))
print (int('0xaa',16))
print (int('1010',2))
# Out:
# 8
# 170
# 10

# %%
0o10
# Out:
# 8

# %% [markdown]
# **int( )** can also be used to get only the integer value of a float number or can be used to convert a number which is of type string to integer format. Similarly, the function **str( )** can be used to convert the integer back to string format

# %% [markdown]
# `int( )`関数はまた`float`の数字の整数部分を取り出すのに使う。
#
# 文字列を整数にするにも使う。このぎゃくは`str()`である。

# %%
print (int(7.7))
print (int('7'))
# Out:
# 7
# 7

# %%
print (int (-3.7))
# Out:
# -3

# %%
import math
print (math.floor(-3.7))
# Out:
# -4

# %%
int("3")
# Out:
# 3

# %%
str(3)
# Out:
# '3'

# %% [markdown]
# Also note that function **bin( )** is used for binary and **float( )** for decimal/float values. **chr( )** is used for converting ASCII to its alphabet equivalent, **ord( )** is used for the other way round.

# %% [markdown]
# `bin( )`関数は数字を二進数に変換する
# `float( )`関数は十進数の`float`に変換する。
# `chr( )`関数は数字をアスキー文字に変換する。
# `ord( )`関数は逆に文字をコード(数字)に変換する。

# %%
bin(32)
# Out:
# '0b100000'

# %%
0b100000
# Out:
# 32

# %%
float(3)
# Out:
# 3.0

# %%
float(3.2)
# Out:
# 3.2

# %%
chr(98)
# Out:
# 'b'

# %%
ord('b')
# Out:
# 98

# %% [markdown]
# ## 算術演算の簡易化 Simplifying Arithmetic Operations

# %% [markdown]
# **round( )** function rounds the input value to a specified number of places or to the nearest integer.

# %% [markdown]
# `round( )`関数は四捨五入

# %%
print (round(5.6231)) 
print (round(4.55892, 2))
# Out:
# 6
# 4.56

# %% [markdown]
# **complex( )** is used to define a complex number and **abs( )** outputs the absolute value of the same.

# %% [markdown]
# `complex( )`関数は複素数を定義するのに使われる。
# `abs( )`関数は絶対値に変換する。

# %%
c =complex('5+2j')
print (abs(c))
# Out:
# 5.385164807134504

# %%
import math
math.sqrt(25+4)
# Out:
# 5.385164807134504

# %% [markdown]
# **divmod(x,y)** outputs the quotient and the remainder in a tuple(you will be learning about it in the further chapters) in the format (quotient, remainder).

# %% [markdown]
# `divmod(x,y)`は商(quotient)と剰余(remainder)をtupleの形で返す。`tuple`については別途学習する。

# %%
divmod(9,2)
# Out:
# (4, 1)

# %%
9 // 2
# Out:
# 4

# %%
9 % 2
# Out:
# 1

# %%
divmod(-9 ,2)
# Out:
# (-5, 1)

# %% [markdown]
# **isinstance( )** returns True, if the first argument is an instance of that class. Multiple classes can also be checked at once.

# %% [markdown]
# `isinstance( )`関数は最初の引数が次の引数のクラスのインスタンスであるかどうかを返す。複数のクラスが指定できる。

# %%
print(isinstance(1, int))
print(isinstance(1.0,int))
print(isinstance(1.0,(int,float)))
# Out:
# True
# False
# True

# %% [markdown]
# `comp()`は大小関係を比較して`1, 0, -1`を返す。=> python3でなくなった。

# %% [markdown]
# **cmp(x,y)**
#
# |x ? y|Output|
# |---|---|
# | x < y | -1 |
# | x == y | 0 |
# | x > y | 1 |

# %% [markdown]
# ## テーブルを左寄せにできないか。

# %% [markdown]
# `comp()`は大小関係を比較して`1, 0, -1`を返す。=> python3でなくなった。
#
# ```
# print(cmp(1,2))
# print(cmp(2,1))
# print(cmp(2,2))
# ```

# %% [markdown]
# **pow(x,y,z)** can be used to find the power $x^y$ also the mod of the resulting value with the third specified number can be found i.e. : ($x^y$ % z).

# %% [markdown]
# `pow(x,y,z)`関数は $x^y$ を計算する。
#
# 3つめに引数があれば、さらに剰余計算をする。すなわち ($x^y$ % $z$)を計算する。

# %%
print(pow(3,3))
print(pow(3,3,5))
# Out:
# 27
# 2

# %% [markdown]
# **range( )** function outputs the integers of the specified range. It can also be used to generate a series by specifying the difference between the two numbers within a particular range. The elements are returned in a list (will be discussing in detail later.)

# %% [markdown]
# `range( )`関数は指定された範囲をリストで返す。

# %%
print(list(range(3)))
print(list(range(2,9)))
print(list(range(2,27,8)))
# Out:
# [0, 1, 2]
# [2, 3, 4, 5, 6, 7, 8]
# [2, 10, 18, 26]

# %% [markdown]
# ## ユーザー入力の受け付け Accepting User Inputs

# %% [markdown]
# **raw_input( )** accepts input and stores it as a string. Hence, if the user inputs a integer, the code should convert the string to an
# integer and then proceed.
#
# => `raw_input()`はなくなりました。python3。

# %%
abc = input()
# Out:
# 3

# %%
print((type(abc)))
print(abc)
# Out:
# <class 'str'>
# 3

# %%
print(int(abc) + 5)
# Out:
# 8

# %%
abc = input("this is a pen  ")
# Out:
# this is a pen  ths

# %%
print(abc)
# Out:
# ths

# %% [markdown]
# プログラムで使う`readline()`はjupyter notebook上ではうまくないので、納得行かないが`input()`を使うことになると思います。
# ```
# import sys
# print("What is your quest?")
# quest = sys.stdin.readline()
# ```

# %% [markdown]
# **input( )**, this is used only for accepting only integer inputs.
#
# これはpython2の話。

# %%
abc1 =  input("Only integer can be stored in variable abc \t")
# Out:
# Only integer can be stored in variable abc 	abc

# %% [markdown]
# これはウソで`input()`は文字列しか受け付けません。

# %%
type(abc1) # => str
# Out:
# str

# %% [markdown]
# Note that **type( )** returns the format or the type of a variable or a number

# %% [markdown]
# `type( )`関数は型を返します。

# %%
type(3.5)
# Out:
# float
